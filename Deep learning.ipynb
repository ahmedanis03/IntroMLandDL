# %%
def display_gif(fn):
    from IPython import display
    return display.HTML('<img src="{}">'.format(fn))

from IPython.display import Image

# %% [markdown]
# # Deep learning vs Normal Machine learning

# %%
Image('MLvsDL.png')

# %% [markdown]
# An example for traditional machine learning: https://www.kaggle.com/the1owl/natural-growth-patterns-fractals-of-nature

# %% [markdown]
# ## How to train Neural Network on images

# %% [markdown]
# ## Deep learning Model Representation

# %% [markdown]
# a multi layer neural networks (above two usually)

# %% [markdown]
# ### What is convultion layer
# local receptive field

# %%
Image('ConvLayer1.jpg')

# %%
Image('ConvLayer2.png')

# %% [markdown]
# ### Another activation function (Relu)

# %%
Image('SigVsRelu.png')

# %% [markdown]
# ### What is pooling layer

# %%
Image('maxpool.jpeg')

# %% [markdown]
# 1. reduce overfitting
# 2. Capture important information only
# 3. reduce memory foot

# %% [markdown]
# ### Convultion layer paramaters

# %% [markdown]
# 1. W (filter size)
# 2. depth
# 3. stride
# 4. padding

# %% [markdown]
# ### Shared weights effects

# %% [markdown]
# http://cs231n.github.io/assets/conv-demo/index.html

# %% [markdown]
# 1. not bound to position or scale

# %% [markdown]
# # Deep learning Father (lecun 1988)

# %%
Image('lenet.png')

# %% [markdown]
# ### Pretrained Case Studies

# %%
Image('PretrainedModelsPerfectRep.png')

# %% [markdown]
# Perfect link for history of pretrained: https://medium.com/towards-data-science/neural-network-architectures-156e5bad51ba

# %% [markdown]
# ### Knowledge Transfer
# fine tuning

# %%
Image('VisConv.png')

# %%
Image('finetune.png')

# %% [markdown]
# ### Deep learning frameworks

# %%
Image('DLFrameworks.png')

# %% [markdown]
# ### Why deep learning can make you in deep depression

# %% [markdown]
# RUN TIME and HARDWARE REQUIRMENTS

# %% [markdown]
# ### Why GPU? Why Nvidia

# %%
Image('cpu-vs-gpu.png')

# %% [markdown]
# ### Specs Required for a deep learning machine

# %% [markdown]
# Fedex solution by Teradata:
#
# file:///C:/Users/AA186096/Downloads/profiling_images_fedex.html
